# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
    city_url = url + "&q=" + city.replace(" ","+")
    city_weather = requests.get(city_url).json()
    
    city_weather
# Out:
# {'coord': {'lon': -73.414, 'lat': 41.3712},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 67.48,
#   'feels_like': 66.56,
#   'temp_min': 66,
#   'temp_max': 70,
#   'pressure': 1013,
#   'humidity': 56},
#  'visibility': 10000,
#  'wind': {'speed': 13.8, 'deg': 240, 'gust': 24.16},
#  'clouds': {'all': 90},
#  'dt': 1618087602,
#  'sys': {'type': 1,
#   'id': 3888,
#   'country': 'US',
#   'sunrise': 1618050081,
#   'sunset': 1618097278},
#  'timezone': -14400,
#  'id': 5282297,
#  'name': 'Bethel',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
len(city_data)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | tiksi
# Processing Record 4 of Set 1 | kaitangata
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | norman wells
# Processing Record 9 of Set 1 | dwarka
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | bosaso
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | iqaluit
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | ancud
# Processing Record 20 of Set 1 | turayf
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | jertih
# Processing Record 23 of Set 1 | omsukchan
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | evensk
# Processing Record 26 of Set 1 | paramonga
# Processing Record 27 of Set 1 | makakilo city
# Processing Record 28 of Set 1 | guane
# Processing Record 29 of Set 1 | dryden
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | ribeira grande
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | mahebourg
# Processing Record 36 of Set 1 | grand gaube
# Processing Record 37 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 1 | cherskiy
# Processing Record 39 of Set 1 | lompoc
# Processing Record 40 of Set 1 | nueva loja
# Processing Record 41 of Set 1 | bandarbeyla
# Processing Record 42 of Set 1 | bloomfield
# Processing Record 43 of Set 1 | ponta do sol
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | chokurdakh
# Processing Record 46 of Set 1 | royan
# Processing Record 47 of Set 1 | veraval
# Processing Record 48 of Set 1 | rosetta
# Processing Record 49 of Set 1 | camopi
# Processing Record 50 of Set 1 | paraiso
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | airai
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | torbay
# Processing Record 6 of Set 2 | mar del plata
# Processing Record 7 of Set 2 | tuatapere
# Processing Record 8 of Set 2 | sangar
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | carnarvon
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | katsuura
# Processing Record 15 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 2 | konstantinovka
# Processing Record 17 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 2 | rio gallegos
# Processing Record 19 of Set 2 | bethel
# Processing Record 20 of Set 2 | mozarlandia
# Processing Record 21 of Set 2 | ruwi
# Processing Record 22 of Set 2 | yulara
# Processing Record 23 of Set 2 | esperance
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | hovd
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | la ronge
# Processing Record 28 of Set 2 | jutai
# Processing Record 29 of Set 2 | luderitz
# Processing Record 30 of Set 2 | uyuni
# Processing Record 31 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 32 of Set 2 | mount isa
# Processing Record 33 of Set 2 | hasaki
# Processing Record 34 of Set 2 | mercedes
# Processing Record 35 of Set 2 | kavieng
# Processing Record 36 of Set 2 | kapaa
# Processing Record 37 of Set 2 | sur
# Processing Record 38 of Set 2 | muros
# Processing Record 39 of Set 2 | wagar
# Processing Record 40 of Set 2 | cabadiangan
# Processing Record 41 of Set 2 | broome
# Processing Record 42 of Set 2 | saint-denis
# Processing Record 43 of Set 2 | bani walid
# Processing Record 44 of Set 2 | pointe michel
# Processing Record 45 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 46 of Set 2 | kuusamo
# Processing Record 47 of Set 2 | westport
# Processing Record 48 of Set 2 | pevek
# Processing Record 49 of Set 2 | yeniseysk
# Processing Record 50 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 3 | boueni
# Processing Record 2 of Set 3 | lavrentiya
# Processing Record 3 of Set 3 | ostersund
# Processing Record 4 of Set 3 | nyurba
# Processing Record 5 of Set 3 | tautira
# Processing Record 6 of Set 3 | tibu
# Processing Record 7 of Set 3 | saint george
# Processing Record 8 of Set 3 | dikson
# Processing Record 9 of Set 3 | riyadh
# Processing Record 10 of Set 3 | dicabisagan
# Processing Record 11 of Set 3 | svetlyy
# Processing Record 12 of Set 3 | bathsheba
# Processing Record 13 of Set 3 | poronaysk
# Processing Record 14 of Set 3 | nouadhibou
# Processing Record 15 of Set 3 | yumen
# Processing Record 16 of Set 3 | zhezkazgan
# Processing Record 17 of Set 3 | rorvik
# Processing Record 18 of Set 3 | lusambo
# Processing Record 19 of Set 3 | tura
# Processing Record 20 of Set 3 | hefei
# Processing Record 21 of Set 3 | meulaboh
# Processing Record 22 of Set 3 | fortuna
# Processing Record 23 of Set 3 | ketchikan
# Processing Record 24 of Set 3 | barro
# Processing Record 25 of Set 3 | kyotera
# Processing Record 26 of Set 3 | qidong
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | margate
# Processing Record 29 of Set 3 | ordynskoye
# Processing Record 30 of Set 3 | cidreira
# Processing Record 31 of Set 3 | san felipe
# Processing Record 32 of Set 3 | puerto suarez
# Processing Record 33 of Set 3 | salalah
# Processing Record 34 of Set 3 | castro
# Processing Record 35 of Set 3 | kruisfontein
# Processing Record 36 of Set 3 | aswan
# Processing Record 37 of Set 3 | vanavara
# Processing Record 38 of Set 3 | singkang
# Processing Record 39 of Set 3 | georgetown
# Processing Record 40 of Set 3 | faya
# Processing Record 41 of Set 3 | dunedin
# Processing Record 42 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 3 | bira
# Processing Record 44 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 3 | codrington
# Processing Record 46 of Set 3 | krasnokamensk
# Processing Record 47 of Set 3 | east london
# Processing Record 48 of Set 3 | zhireken
# Processing Record 49 of Set 3 | komsomolskiy
# Processing Record 50 of Set 3 | guanica
# Processing Record 1 of Set 4 | kununurra
# Processing Record 2 of Set 4 | itacare
# Processing Record 3 of Set 4 | korcula
# Processing Record 4 of Set 4 | natchez
# Processing Record 5 of Set 4 | laguna
# Processing Record 6 of Set 4 | xichang
# Processing Record 7 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 4 | muzhi
# Processing Record 9 of Set 4 | sakakah
# Processing Record 10 of Set 4 | san quintin
# Processing Record 11 of Set 4 | richards bay
# Processing Record 12 of Set 4 | yantal
# Processing Record 13 of Set 4 | faanui
# Processing Record 14 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 15 of Set 4 | nkhata bay
# Processing Record 16 of Set 4 | rockhampton
# Processing Record 17 of Set 4 | balakliya
# Processing Record 18 of Set 4 | halifax
# Processing Record 19 of Set 4 | nanortalik
# Processing Record 20 of Set 4 | palana
# Processing Record 21 of Set 4 | sorland
# Processing Record 22 of Set 4 | balkanabat
# Processing Record 23 of Set 4 | camacha
# Processing Record 24 of Set 4 | alofi
# Processing Record 25 of Set 4 | yangjiang
# Processing Record 26 of Set 4 | kutum
# Processing Record 27 of Set 4 | quang ngai
# Processing Record 28 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 4 | lebu
# Processing Record 30 of Set 4 | catamarca
# Processing Record 31 of Set 4 | arys
# Processing Record 32 of Set 4 | constitucion
# Processing Record 33 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 35 of Set 4 | te anau
# Processing Record 36 of Set 4 | saskylakh
# Processing Record 37 of Set 4 | sambava
# Processing Record 38 of Set 4 | tuktoyaktuk
# Processing Record 39 of Set 4 | avarua
# Processing Record 40 of Set 4 | leeton
# Processing Record 41 of Set 4 | port augusta
# Processing Record 42 of Set 4 | puerto ayora
# Processing Record 43 of Set 4 | qaqortoq
# Processing Record 44 of Set 4 | murchison
# Processing Record 45 of Set 4 | upernavik
# Processing Record 46 of Set 4 | jennings
# Processing Record 47 of Set 4 | khatanga
# Processing Record 48 of Set 4 | leon
# Processing Record 49 of Set 4 | hauterive
# Processing Record 50 of Set 4 | weyburn
# Processing Record 1 of Set 5 | salinopolis
# Processing Record 2 of Set 5 | carutapera
# Processing Record 3 of Set 5 | bambous virieux
# Processing Record 4 of Set 5 | jodhpur
# Processing Record 5 of Set 5 | dudinka
# Processing Record 6 of Set 5 | jiwani
# Processing Record 7 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 5 | olongapo
# Processing Record 10 of Set 5 | semme
# Processing Record 11 of Set 5 | noumea
# Processing Record 12 of Set 5 | panshi
# Processing Record 13 of Set 5 | scicli
# Processing Record 14 of Set 5 | benito juarez
# Processing Record 15 of Set 5 | manta
# Processing Record 16 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 5 | cockburn town
# Processing Record 18 of Set 5 | hithadhoo
# Processing Record 19 of Set 5 | taltal
# Processing Record 20 of Set 5 | luau
# Processing Record 21 of Set 5 | thompson
# Processing Record 22 of Set 5 | mayo
# Processing Record 23 of Set 5 | kaputa
# Processing Record 24 of Set 5 | comodoro rivadavia
# Processing Record 25 of Set 5 | nha trang
# Processing Record 26 of Set 5 | qixingtai
# Processing Record 27 of Set 5 | nome
# Processing Record 28 of Set 5 | dagup
# Processing Record 29 of Set 5 | bilibino
# Processing Record 30 of Set 5 | rosario oeste
# Processing Record 31 of Set 5 | avera
# Processing Record 32 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 5 | oyama
# Processing Record 34 of Set 5 | newport
# Processing Record 35 of Set 5 | borova
# Processing Record 36 of Set 5 | bengkulu
# Processing Record 37 of Set 5 | sola
# Processing Record 38 of Set 5 | mabaruma
# Processing Record 39 of Set 5 | vostok
# Processing Record 40 of Set 5 | sagarejo
# Processing Record 41 of Set 5 | la malbaie
# Processing Record 42 of Set 5 | san patricio
# Processing Record 43 of Set 5 | zheleznodorozhnyy
# Processing Record 44 of Set 5 | aripuana
# Processing Record 45 of Set 5 | ikalamavony
# Processing Record 46 of Set 5 | lodja
# Processing Record 47 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 5 | san juan
# Processing Record 49 of Set 5 | bhikangaon
# Processing Record 50 of Set 5 | simao
# Processing Record 1 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 6 | voh
# Processing Record 3 of Set 6 | padang
# Processing Record 4 of Set 6 | victor harbor
# Processing Record 5 of Set 6 | pisco
# Processing Record 6 of Set 6 | maxixe
# Processing Record 7 of Set 6 | palmer
# Processing Record 8 of Set 6 | warmbad
# Processing Record 9 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 6 | mount gambier
# Processing Record 11 of Set 6 | dongying
# Processing Record 12 of Set 6 | port moresby
# Processing Record 13 of Set 6 | tezu
# Processing Record 14 of Set 6 | vitim
# Processing Record 15 of Set 6 | barranca
# Processing Record 16 of Set 6 | natal
# Processing Record 17 of Set 6 | lakes entrance
# Processing Record 18 of Set 6 | ovsyanka
# Processing Record 19 of Set 6 | okhotsk
# Processing Record 20 of Set 6 | leningradskiy
# Processing Record 21 of Set 6 | geraldton
# Processing Record 22 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 6 | talaya
# Processing Record 24 of Set 6 | guerrero negro
# Processing Record 25 of Set 6 | port hardy
# Processing Record 26 of Set 6 | samana
# Processing Record 27 of Set 6 | visby
# Processing Record 28 of Set 6 | dawei
# Processing Record 29 of Set 6 | goundam
# Processing Record 30 of Set 6 | huarmey
# Processing Record 31 of Set 6 | berga
# Processing Record 32 of Set 6 | shadrinsk
# Processing Record 33 of Set 6 | rocha
# Processing Record 34 of Set 6 | verkhnevilyuysk
# Processing Record 35 of Set 6 | canutama
# Processing Record 36 of Set 6 | namibe
# Processing Record 37 of Set 6 | daru
# Processing Record 38 of Set 6 | arman
# Processing Record 39 of Set 6 | chuy
# Processing Record 40 of Set 6 | middleton
# Processing Record 41 of Set 6 | talnakh
# Processing Record 42 of Set 6 | macaboboni
# City not found. Skipping...
# Processing Record 43 of Set 6 | kendari
# Processing Record 44 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 6 | rawah
# Processing Record 46 of Set 6 | ilo
# Processing Record 47 of Set 6 | ojinaga
# Processing Record 48 of Set 6 | chiang khong
# Processing Record 49 of Set 6 | lisakovsk
# Processing Record 50 of Set 6 | port macquarie
# Processing Record 1 of Set 7 | vaasa
# Processing Record 2 of Set 7 | plettenberg bay
# Processing Record 3 of Set 7 | ornes
# Processing Record 4 of Set 7 | kokkola
# Processing Record 5 of Set 7 | bucerias
# Processing Record 6 of Set 7 | tyukhtet
# Processing Record 7 of Set 7 | port blair
# Processing Record 8 of Set 7 | cabedelo
# Processing Record 9 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 10 of Set 7 | pindiga
# Processing Record 11 of Set 7 | isangel
# Processing Record 12 of Set 7 | umm bab
# Processing Record 13 of Set 7 | usinsk
# Processing Record 14 of Set 7 | tasiilaq
# Processing Record 15 of Set 7 | krasnoselkup
# Processing Record 16 of Set 7 | klaksvik
# Processing Record 17 of Set 7 | lingao
# Processing Record 18 of Set 7 | hofn
# Processing Record 19 of Set 7 | aksarka
# Processing Record 20 of Set 7 | inirida
# Processing Record 21 of Set 7 | kang
# Processing Record 22 of Set 7 | giyani
# Processing Record 23 of Set 7 | harper
# Processing Record 24 of Set 7 | inuvik
# Processing Record 25 of Set 7 | tukrah
# Processing Record 26 of Set 7 | sawakin
# Processing Record 27 of Set 7 | namatanai
# Processing Record 28 of Set 7 | eyl
# Processing Record 29 of Set 7 | ilulissat
# Processing Record 30 of Set 7 | roma
# Processing Record 31 of Set 7 | bara
# Processing Record 32 of Set 7 | kasongo-lunda
# Processing Record 33 of Set 7 | omboue
# Processing Record 34 of Set 7 | estelle
# Processing Record 35 of Set 7 | severo-kurilsk
# Processing Record 36 of Set 7 | beyneu
# Processing Record 37 of Set 7 | preobrazheniye
# Processing Record 38 of Set 7 | sanchursk
# Processing Record 39 of Set 7 | ranong
# Processing Record 40 of Set 7 | brae
# Processing Record 41 of Set 7 | blackwater
# Processing Record 42 of Set 7 | maceio
# Processing Record 43 of Set 7 | la palma
# Processing Record 44 of Set 7 | camacari
# Processing Record 45 of Set 7 | magadan
# Processing Record 46 of Set 7 | bajil
# Processing Record 47 of Set 7 | okha
# Processing Record 48 of Set 7 | port lincoln
# Processing Record 49 of Set 7 | jackson
# Processing Record 50 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 1 of Set 8 | cedar city
# Processing Record 2 of Set 8 | kavaratti
# Processing Record 3 of Set 8 | turba
# Processing Record 4 of Set 8 | ligayan
# Processing Record 5 of Set 8 | nanlong
# Processing Record 6 of Set 8 | tambacounda
# Processing Record 7 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 8 | alice springs
# Processing Record 9 of Set 8 | grindavik
# Processing Record 10 of Set 8 | kerema
# Processing Record 11 of Set 8 | buala
# Processing Record 12 of Set 8 | garissa
# Processing Record 13 of Set 8 | buraydah
# Processing Record 14 of Set 8 | berlevag
# Processing Record 15 of Set 8 | eureka
# Processing Record 16 of Set 8 | diu
# Processing Record 17 of Set 8 | gebre guracha
# Processing Record 18 of Set 8 | benguela
# Processing Record 19 of Set 8 | birjand
# Processing Record 20 of Set 8 | ico
# Processing Record 21 of Set 8 | marsh harbour
# Processing Record 22 of Set 8 | narok
# Processing Record 23 of Set 8 | acarau
# Processing Record 24 of Set 8 | wichita falls
# Processing Record 25 of Set 8 | helong
# Processing Record 26 of Set 8 | bobo dioulasso
# Processing Record 27 of Set 8 | adrar
# Processing Record 28 of Set 8 | basco
# Processing Record 29 of Set 8 | polonnaruwa
# Processing Record 30 of Set 8 | tual
# Processing Record 31 of Set 8 | chenzhou
# Processing Record 32 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 8 | flinders
# Processing Record 34 of Set 8 | guozhen
# Processing Record 35 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 8 | lexington
# Processing Record 37 of Set 8 | clyde river
# Processing Record 38 of Set 8 | uvira
# Processing Record 39 of Set 8 | khani
# Processing Record 40 of Set 8 | ahipara
# Processing Record 41 of Set 8 | benemerito de las americas
# Processing Record 42 of Set 8 | churapcha
# Processing Record 43 of Set 8 | mitsamiouli
# Processing Record 44 of Set 8 | inta
# Processing Record 45 of Set 8 | opuwo
# Processing Record 46 of Set 8 | ramanuj ganj
# Processing Record 47 of Set 8 | san vicente de canete
# Processing Record 48 of Set 8 | saldanha
# Processing Record 49 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 8 | vardo
# Processing Record 1 of Set 9 | curup
# Processing Record 2 of Set 9 | tambura
# Processing Record 3 of Set 9 | umm kaddadah
# Processing Record 4 of Set 9 | miguel hidalgo
# Processing Record 5 of Set 9 | monte alegre
# Processing Record 6 of Set 9 | ciras
# City not found. Skipping...
# Processing Record 7 of Set 9 | poum
# Processing Record 8 of Set 9 | marystown
# Processing Record 9 of Set 9 | maltahohe
# Processing Record 10 of Set 9 | santa maria
# Processing Record 11 of Set 9 | doka
# Processing Record 12 of Set 9 | nikolskoye
# Processing Record 13 of Set 9 | mizdah
# Processing Record 14 of Set 9 | potgietersrus
# City not found. Skipping...
# Processing Record 15 of Set 9 | batagay-alyta
# Processing Record 16 of Set 9 | hisor
# Processing Record 17 of Set 9 | sudak
# Processing Record 18 of Set 9 | anloga
# Processing Record 19 of Set 9 | beinamar
# Processing Record 20 of Set 9 | hamilton
# Processing Record 21 of Set 9 | eenhana
# Processing Record 22 of Set 9 | isfana
# Processing Record 23 of Set 9 | gouyave
# Processing Record 24 of Set 9 | acapulco
# Processing Record 25 of Set 9 | sharlyk
# Processing Record 26 of Set 9 | quatre cocos
# Processing Record 27 of Set 9 | coahuayana
# Processing Record 28 of Set 9 | kloulklubed
# Processing Record 29 of Set 9 | poyarkovo
# Processing Record 30 of Set 9 | dubbo
# Processing Record 31 of Set 9 | hami
# Processing Record 32 of Set 9 | paragominas
# Processing Record 33 of Set 9 | half moon bay
# Processing Record 34 of Set 9 | zhigansk
# Processing Record 35 of Set 9 | bubaque
# Processing Record 36 of Set 9 | samarai
# Processing Record 37 of Set 9 | genhe
# Processing Record 38 of Set 9 | miri
# Processing Record 39 of Set 9 | arroyo
# Processing Record 40 of Set 9 | sorong
# Processing Record 41 of Set 9 | floresti
# Processing Record 42 of Set 9 | xining
# Processing Record 43 of Set 9 | obala
# Processing Record 44 of Set 9 | barroualie
# City not found. Skipping...
# Processing Record 45 of Set 9 | skeldon
# Processing Record 46 of Set 9 | kurumkan
# Processing Record 47 of Set 9 | aklavik
# Processing Record 48 of Set 9 | patan
# Processing Record 49 of Set 9 | bitung
# Processing Record 50 of Set 9 | phangnga
# Processing Record 1 of Set 10 | souillac
# Processing Record 2 of Set 10 | barberton
# Processing Record 3 of Set 10 | aguimes
# Processing Record 4 of Set 10 | fairbanks
# Processing Record 5 of Set 10 | kijang
# Processing Record 6 of Set 10 | qui nhon
# Processing Record 7 of Set 10 | manjeshwar
# Processing Record 8 of Set 10 | gravdal
# Processing Record 9 of Set 10 | issia
# Processing Record 10 of Set 10 | batagay
# Processing Record 11 of Set 10 | toungoo
# City not found. Skipping...
# Processing Record 12 of Set 10 | victoria
# Processing Record 13 of Set 10 | maldonado
# Processing Record 14 of Set 10 | talcahuano
# Processing Record 15 of Set 10 | husavik
# Processing Record 16 of Set 10 | kahului
# Processing Record 17 of Set 10 | wajir
# Processing Record 18 of Set 10 | ongandjera
# Processing Record 19 of Set 10 | progreso
# Processing Record 20 of Set 10 | victoria point
# Processing Record 21 of Set 10 | qasigiannguit
# Processing Record 22 of Set 10 | iskilip
# Processing Record 23 of Set 10 | yatou
# Processing Record 24 of Set 10 | entre rios
# Processing Record 25 of Set 10 | khandyga
# Processing Record 26 of Set 10 | songjianghe
# Processing Record 27 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 28 of Set 10 | coquimbo
# Processing Record 29 of Set 10 | rantepao
# Processing Record 30 of Set 10 | jardim
# Processing Record 31 of Set 10 | miraflores
# Processing Record 32 of Set 10 | linxia
# Processing Record 33 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 10 | santa isabel do rio negro
# Processing Record 35 of Set 10 | shimanovsk
# Processing Record 36 of Set 10 | saint-joseph
# Processing Record 37 of Set 10 | tambopata
# Processing Record 38 of Set 10 | killybegs
# Processing Record 39 of Set 10 | kalur kot
# Processing Record 40 of Set 10 | rawson
# Processing Record 41 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 10 | lorengau
# Processing Record 43 of Set 10 | bokaa
# Processing Record 44 of Set 10 | varberg
# Processing Record 45 of Set 10 | hambantota
# Processing Record 46 of Set 10 | lerwick
# Processing Record 47 of Set 10 | khed
# Processing Record 48 of Set 10 | pandan
# Processing Record 49 of Set 10 | praia
# Processing Record 50 of Set 10 | maimon
# City not found. Skipping...
# Processing Record 1 of Set 11 | zeya
# Processing Record 2 of Set 11 | raahe
# Processing Record 3 of Set 11 | erenhot
# Processing Record 4 of Set 11 | bardiyah
# Processing Record 5 of Set 11 | betong
# Processing Record 6 of Set 11 | kudat
# Processing Record 7 of Set 11 | kushmurun
# Processing Record 8 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 11 | binzhou
# Processing Record 10 of Set 11 | san jose
# Processing Record 11 of Set 11 | ossora
# Processing Record 12 of Set 11 | najran
# Processing Record 13 of Set 11 | rey bouba
# Processing Record 14 of Set 11 | aldan
# Processing Record 15 of Set 11 | necochea
# Processing Record 16 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 17 of Set 11 | aksu
# Processing Record 18 of Set 11 | vakhrushev
# Processing Record 19 of Set 11 | sao joao da barra
# Processing Record 20 of Set 11 | ust-nera
# Processing Record 21 of Set 11 | vestbygda
# City not found. Skipping...
# Processing Record 22 of Set 11 | vao
# Processing Record 23 of Set 11 | meadow lake
# Processing Record 24 of Set 11 | wum
# Processing Record 25 of Set 11 | dingle
# Processing Record 26 of Set 11 | agucadoura
# Processing Record 27 of Set 11 | sechura
# Processing Record 28 of Set 11 | lecce
# Processing Record 29 of Set 11 | henties bay
# Processing Record 30 of Set 11 | bay city
# Processing Record 31 of Set 11 | naze
# Processing Record 32 of Set 11 | bahile
# Processing Record 33 of Set 11 | kazan
# Processing Record 34 of Set 11 | dong hoi
# Processing Record 35 of Set 11 | north platte
# Processing Record 36 of Set 11 | kudahuvadhoo
# Processing Record 37 of Set 11 | bambanglipuro
# Processing Record 38 of Set 11 | narsaq
# Processing Record 39 of Set 11 | mindelo
# Processing Record 40 of Set 11 | cairns
# Processing Record 41 of Set 11 | port shepstone
# Processing Record 42 of Set 11 | havoysund
# Processing Record 43 of Set 11 | zhicheng
# Processing Record 44 of Set 11 | belmonte
# Processing Record 45 of Set 11 | ibra
# Processing Record 46 of Set 11 | ahuimanu
# Processing Record 47 of Set 11 | svarstad
# Processing Record 48 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 49 of Set 11 | lujiang
# Processing Record 50 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 12 | college
# Processing Record 2 of Set 12 | hajiganj
# Processing Record 3 of Set 12 | benicarlo
# Processing Record 4 of Set 12 | tiznit
# Processing Record 5 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 6 of Set 12 | posse
# Processing Record 7 of Set 12 | ugoofaaru
# Processing Record 8 of Set 12 | kerki
# City not found. Skipping...
# Processing Record 9 of Set 12 | asau
# Processing Record 10 of Set 12 | puerto asis
# Processing Record 11 of Set 12 | skhisma
# Processing Record 12 of Set 12 | great falls
# Processing Record 13 of Set 12 | birin
# Processing Record 14 of Set 12 | san andres
# Processing Record 15 of Set 12 | awbari
# Processing Record 16 of Set 12 | lima
# Processing Record 17 of Set 12 | hay river
# Processing Record 18 of Set 12 | wanaka
# Processing Record 19 of Set 12 | balkhash
# Processing Record 20 of Set 12 | kaman
# Processing Record 21 of Set 12 | torit
# Processing Record 22 of Set 12 | labuhan
# Processing Record 23 of Set 12 | ewa beach
# Processing Record 24 of Set 12 | sinnamary
# Processing Record 25 of Set 12 | vila velha
# Processing Record 26 of Set 12 | kieta
# Processing Record 27 of Set 12 | taveta
# Processing Record 28 of Set 12 | duz
# City not found. Skipping...
# Processing Record 29 of Set 12 | deputatskiy
# Processing Record 30 of Set 12 | pimentel
# Processing Record 31 of Set 12 | shevchenkove
# Processing Record 32 of Set 12 | twentynine palms
# Processing Record 33 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 12 | moose factory
# Processing Record 35 of Set 12 | portoferraio
# Processing Record 36 of Set 12 | verkh-suetka
# Processing Record 37 of Set 12 | mardin
# Processing Record 38 of Set 12 | tambilil
# Processing Record 39 of Set 12 | tessalit
# Processing Record 40 of Set 12 | sao marcos
# Processing Record 41 of Set 12 | gumushane
# City not found. Skipping...
# Processing Record 42 of Set 12 | tanete
# Processing Record 43 of Set 12 | beringovskiy
# Processing Record 44 of Set 12 | waycross
# Processing Record 45 of Set 12 | deniliquin
# Processing Record 46 of Set 12 | road town
# Processing Record 47 of Set 12 | bairiki
# Processing Record 48 of Set 12 | sao filipe
# Processing Record 49 of Set 12 | yeppoon
# Processing Record 50 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 1 of Set 13 | takoradi
# Processing Record 2 of Set 13 | rong kwang
# Processing Record 3 of Set 13 | panguna
# Processing Record 4 of Set 13 | san cristobal
# Processing Record 5 of Set 13 | uniara
# Processing Record 6 of Set 13 | svetlogorsk
# Processing Record 7 of Set 13 | teya
# Processing Record 8 of Set 13 | beloha
# Processing Record 9 of Set 13 | mont-de-marsan
# Processing Record 10 of Set 13 | ishinomaki
# Processing Record 11 of Set 13 | katsiveli
# City not found. Skipping...
# Processing Record 12 of Set 13 | kulhudhuffushi
# Processing Record 13 of Set 13 | inhambane
# Processing Record 14 of Set 13 | asyut
# Processing Record 15 of Set 13 | luganville
# Processing Record 16 of Set 13 | denpasar
# Processing Record 17 of Set 13 | manakara
# Processing Record 18 of Set 13 | ballina
# Processing Record 19 of Set 13 | shache
# Processing Record 20 of Set 13 | shangzhi
# Processing Record 21 of Set 13 | les escoumins
# Processing Record 22 of Set 13 | bartica
# Processing Record 23 of Set 13 | katobu
# Processing Record 24 of Set 13 | cotorra
# Processing Record 25 of Set 13 | barra do garcas
# Processing Record 26 of Set 13 | springbok
# Processing Record 27 of Set 13 | cap malheureux
# Processing Record 28 of Set 13 | saint-augustin
# Processing Record 29 of Set 13 | cabo san lucas
# Processing Record 30 of Set 13 | soyo
# Processing Record 31 of Set 13 | terenos
# Processing Record 32 of Set 13 | jiaocheng
# Processing Record 33 of Set 13 | ravar
# Processing Record 34 of Set 13 | sampit
# Processing Record 35 of Set 13 | los llanos de aridane
# Processing Record 36 of Set 13 | fiumicino
# Processing Record 37 of Set 13 | sitka
# Processing Record 38 of Set 13 | kirakira
# Processing Record 39 of Set 13 | flin flon
# Processing Record 40 of Set 13 | villa maria
# Processing Record 41 of Set 13 | cosala
# Processing Record 42 of Set 13 | majene
# Processing Record 43 of Set 13 | vakhtan
# Processing Record 44 of Set 13 | dickinson
# Processing Record 45 of Set 13 | nantucket
# Processing Record 46 of Set 13 | nhulunbuy
# Processing Record 47 of Set 13 | festus
# Processing Record 48 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 49 of Set 13 | macheng
# Processing Record 50 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 14 | sencur
# Processing Record 2 of Set 14 | kalmunai
# Processing Record 3 of Set 14 | pafos
# Processing Record 4 of Set 14 | mangaluru
# Processing Record 5 of Set 14 | himora
# City not found. Skipping...
# Processing Record 6 of Set 14 | jalu
# Processing Record 7 of Set 14 | kluang
# Processing Record 8 of Set 14 | ruteng
# Processing Record 9 of Set 14 | fort nelson
# Processing Record 10 of Set 14 | ambon
# Processing Record 11 of Set 14 | praya
# Processing Record 12 of Set 14 | bosanski brod
# Processing Record 13 of Set 14 | bereda
# Processing Record 14 of Set 14 | dzaoudzi
# Processing Record 15 of Set 14 | qabaqcol
# Processing Record 16 of Set 14 | georgiyevka
# Processing Record 17 of Set 14 | mandurah
# Processing Record 18 of Set 14 | koraput
# Processing Record 19 of Set 14 | saint combs
# City not found. Skipping...
# Processing Record 20 of Set 14 | panzhihua
# Processing Record 21 of Set 14 | gayeri
# Processing Record 22 of Set 14 | itarema
# Processing Record 23 of Set 14 | iskateley
# Processing Record 24 of Set 14 | ilinskoye-khovanskoye
# Processing Record 25 of Set 14 | kimparana
# Processing Record 26 of Set 14 | kidal
# Processing Record 27 of Set 14 | ouadda
# Processing Record 28 of Set 14 | tonantins
# Processing Record 29 of Set 14 | torun
# Processing Record 30 of Set 14 | huntsville
# Processing Record 31 of Set 14 | pasinler
# Processing Record 32 of Set 14 | leh
# Processing Record 33 of Set 14 | tazovskiy
# Processing Record 34 of Set 14 | kalol
# Processing Record 35 of Set 14 | xinpu
# Processing Record 36 of Set 14 | freeport
# Processing Record 37 of Set 14 | gimli
# Processing Record 38 of Set 14 | mayumba
# Processing Record 39 of Set 14 | caravelas
# Processing Record 40 of Set 14 | chokwe
# Processing Record 41 of Set 14 | banyuwangi
# Processing Record 42 of Set 14 | dukat
# Processing Record 43 of Set 14 | batticaloa
# Processing Record 44 of Set 14 | eydhafushi
# Processing Record 45 of Set 14 | copiapo
# Processing Record 46 of Set 14 | teahupoo
# Processing Record 47 of Set 14 | nea playia
# Processing Record 48 of Set 14 | fortaleza
# Processing Record 49 of Set 14 | taoudenni
# Processing Record 50 of Set 14 | altay
# Processing Record 1 of Set 15 | thinadhoo
# Processing Record 2 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 3 of Set 15 | honiara
# Processing Record 4 of Set 15 | taseyevo
# Processing Record 5 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 6 of Set 15 | pital
# Processing Record 7 of Set 15 | kysyl-syr
# Processing Record 8 of Set 15 | zapolyarnyy
# Processing Record 9 of Set 15 | chimbote
# Processing Record 10 of Set 15 | praia da vitoria
# Processing Record 11 of Set 15 | kachiry
# Processing Record 12 of Set 15 | inyonga
# Processing Record 13 of Set 15 | porto santo
# Processing Record 14 of Set 15 | cherepovets
# Processing Record 15 of Set 15 | vila franca do campo
# Processing Record 16 of Set 15 | saint-georges
# Processing Record 17 of Set 15 | vangaindrano
# Processing Record 18 of Set 15 | fernandez
# Processing Record 19 of Set 15 | maues
# Processing Record 20 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 15 | araioses
# Processing Record 22 of Set 15 | sinjar
# Processing Record 23 of Set 15 | vestmanna
# Processing Record 24 of Set 15 | sao jose da coroa grande
# Processing Record 25 of Set 15 | zhigalovo
# Processing Record 26 of Set 15 | almenevo
# City not found. Skipping...
# Processing Record 27 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 15 | guicheng
# City not found. Skipping...
# Processing Record 29 of Set 15 | mackay
# Processing Record 30 of Set 15 | payo
# Processing Record 31 of Set 15 | trinidad
# Processing Record 32 of Set 15 | srednekolymsk
# Processing Record 33 of Set 15 | novomikhaylovskiy
# Processing Record 34 of Set 15 | marivan
# Processing Record 35 of Set 15 | tomatlan
# Processing Record 36 of Set 15 | sao felix do xingu
# Processing Record 37 of Set 15 | opobo
# City not found. Skipping...
# Processing Record 38 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 15 | olavarria
# Processing Record 40 of Set 15 | ostrovnoy
# Processing Record 41 of Set 15 | las matas de farfan
# Processing Record 42 of Set 15 | hobyo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 680

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Saint-Philippe -21.3585   55.7679     78.80        69           0
# 1          Rikitea -23.1203 -134.9692     78.73        72           0
# 2            Tiksi  71.6872  128.8694    -14.69        98          41
# 3       Kaitangata -46.2817  169.8464     58.75        74          61
# 4        Cape Town -33.9258   18.4232     64.00        88           0
# 5  Arraial Do Cabo -22.9661  -42.0278     78.80        65           0
# 6          Mataura -46.1927  168.8643     57.99        95          65
# 7     Norman Wells  65.2820 -126.8329     -7.60        71          90
# 8           Dwarka  22.2394   68.9678     79.32        73           0
# 9        Busselton -33.6500  115.3333     62.01        77         100
#
#    Wind Speed Country Current Description
# 0        3.44      RE          light rain
# 1       10.02      PF          light rain
# 2        5.66      RU    scattered clouds
# 3        3.71      NZ       broken clouds
# 4       10.36      ZA           clear sky
# 5       17.27      BR           clear sky
# 6        2.46      NZ       broken clouds
# 7        9.22      CA          light snow
# 8       12.68      IN           clear sky
# 9        7.00      AU          light rain

# %%
# Reorder the column order
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Saint-Philippe      RE -21.3585   55.7679     78.80        69
# 1                Rikitea      PF -23.1203 -134.9692     78.73        72
# 2                  Tiksi      RU  71.6872  128.8694    -14.69        98
# 3             Kaitangata      NZ -46.2817  169.8464     58.75        74
# 4              Cape Town      ZA -33.9258   18.4232     64.00        88
# ..                   ...     ...      ...       ...       ...       ...
# 675   Sao Felix Do Xingu      BR  -6.6447  -51.9950     76.19        91
# 676            Olavarria      AR -36.8927  -60.3225     57.99        98
# 677            Ostrovnoy      RU  68.0531   39.5131     33.24        84
# 678  Las Matas De Farfan      DO  18.8731  -71.5166     84.18        44
# 679                Hobyo      SO   5.3505   48.5268     82.58        65
#
#      Cloudiness  Wind Speed Current Description
# 0             0        3.44          light rain
# 1             0       10.02          light rain
# 2            41        5.66    scattered clouds
# 3            61        3.71       broken clouds
# 4             0       10.36           clear sky
# ..          ...         ...                 ...
# 675         100        2.86          light rain
# 676         100        5.01     overcast clouds
# 677          58       25.97       broken clouds
# 678          70        3.83       broken clouds
# 679           6       14.65           clear sky
#
# [680 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
